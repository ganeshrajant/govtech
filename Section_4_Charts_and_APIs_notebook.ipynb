# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import requests
import plotly.express as px

# %%
url = "https://api.covid19api.com/country/singapore/status/confirmed"

payload={}
headers = {}

# extract the data from the covidapi
response = requests.request("GET", url, headers=headers, data=payload)

if response.status_code == 200:
  print(f"Extraction successfull")
# Out:
# Extraction successfull

# %%
print(f"Extraction Data: \n\n {response.text}")
# Out:
# Extraction Data:
#
#  [{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":0,"Status":"confirmed","Date":"2020-01-22T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":1,"Status":"confirmed","Date":"2020-01-23T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":3,"Status":"confirmed","Date":"2020-01-24T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":3,"Status":"confirmed","Date":"2020-01-25T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":4,"Status":"confirmed","Date":"2020-01-26T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":5,"Status":"confirmed","Date":"2020-01-27T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":7,"Status":"confirmed","Date":"2020-01-28T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":7,"Status":"confirmed","Date":"2020-01-29T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":10,"Status":"confirmed","Date":"2020-01-30T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":13,"Status":"confirmed","Date":"2020-01-31T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":16,"Status":"confirmed","Date":"2020-02-01T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":18,"Status":"confirmed","Date":"2020-02-02T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":18,"Status":"confirmed","Date":"2020-02-03T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":24,"Status":"confirmed","Date":"2020-02-04T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":28,"Status":"confirmed","Date":"2020-02-05T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":28,"Status":"confirmed","Date":"2020-02-06T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":30,"Status":"confirmed","Date":"2020-02-07T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":33,"Status":"confirmed","Date":"2020-02-08T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":40,"Status":"confirmed","Date":"2020-02-09T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":45,"Status":"confirmed","Date":"2020-02-10T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":47,"Status":"confirmed","Date":"2020-02-11T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":50,"Status":"confirmed","Date":"2020-02-12T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCode":"","Lat":"1.35","Lon":"103.82","Cases":58,"Status":"confirmed","Date":"2020-02-13T00:00:00Z"},{"Country":"Singapore","CountryCode":"SG","Province":"","City":"","CityCo ...

# %%
# Convert the response text to list of dictionary to make it usable for pandas dataframe
singapore_covid_data = list(eval(response.text))

print(f"Singapore Covid Data over time: \n\n {singapore_covid_data}")
# Out:
# Singapore Covid Data over time:
#
#  [{'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 0, 'Status': 'confirmed', 'Date': '2020-01-22T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 1, 'Status': 'confirmed', 'Date': '2020-01-23T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 3, 'Status': 'confirmed', 'Date': '2020-01-24T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 3, 'Status': 'confirmed', 'Date': '2020-01-25T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 4, 'Status': 'confirmed', 'Date': '2020-01-26T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 5, 'Status': 'confirmed', 'Date': '2020-01-27T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 7, 'Status': 'confirmed', 'Date': '2020-01-28T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 7, 'Status': 'confirmed', 'Date': '2020-01-29T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 10, 'Status': 'confirmed', 'Date': '2020-01-30T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 13, 'Status': 'confirmed', 'Date': '2020-01-31T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 16, 'Status': 'confirmed', 'Date': '2020-02-01T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 18, 'Status': 'confirmed', 'Date': '2020-02-02T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 18, 'Status': 'confirmed', 'Date': '2020-02-03T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 24, 'Status': 'confirmed', 'Date': '2020-02-04T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 28, 'Status': 'confirmed', 'Date': '2020-02-05T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 28, 'Status': 'confirmed', 'Date': '2020-02-06T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 30, 'Status': 'confirmed', 'Date': '2020-02-07T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 33, 'Status': 'confirmed', 'Date': '2020-02-08T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 40, 'Status': 'confirmed', 'Date': '2020-02-09T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 45, 'Status': 'confirmed', 'Date': '2020-02-10T00:00:00Z'}, {'Country': 'Singapore', 'CountryCode': 'SG', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '1.35', 'Lon': '103.82', 'Cases': 47, 'Status': 'confirmed', 'Date': '2020-02-11T00:00:00 ...

# %%
# Convert the singapore covid data to a pandas dataframe
singapore_covid_df = pd.DataFrame(singapore_covid_data)
singapore_covid_df.head()
# Out:
#      Country CountryCode Province  ... Cases     Status                  Date
# 0  Singapore          SG           ...     0  confirmed  2020-01-22T00:00:00Z
# 1  Singapore          SG           ...     1  confirmed  2020-01-23T00:00:00Z
# 2  Singapore          SG           ...     3  confirmed  2020-01-24T00:00:00Z
# 3  Singapore          SG           ...     3  confirmed  2020-01-25T00:00:00Z
# 4  Singapore          SG           ...     4  confirmed  2020-01-26T00:00:00Z
#
# [5 rows x 10 columns]

# %%
# Plot the chart for confirmed cases over time
line_chart = singapore_covid_df.loc[:, ['Date', 'Cases']]

fig = px.line(line_chart, x='Date', y='Cases')
fig.update_layout(xaxis=dict(tickformat='%d-%m-%Y'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9f7c351c-ff95-4b28-adf6-178b96ea7716" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f7c351c-ff95-4b28-adf6-178b96ea7716")) {
#                     Plotly.newPlot(
#                         '9f7c351c-ff95-4b28-adf6-178b96ea7716',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Cases=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["2020-01-22T00:00:00Z", "2020-01-23T00:00:00Z", "2020-01-24T00:00:00Z", "2020-01-25T00:00:00Z", "2020-01-26T00:00:00Z", "2020-01-27T00:00:00Z", "2020-01-28T00:00:00Z", "2020-01-29T00:00:00Z", "2020-01-30T00:00:00Z", "2020-01-31T00:00:00Z", "2020-02-01T00:00:00Z", "2020-02-02T00:00:00Z", "2020-02-03T00:00:00Z", "2020-02-04T00:00:00Z", "2020-02-05T00:00:00Z", "2020-02-06T00:00:00Z", "2020-02-07T00:00:00Z", "2020-02-08T00:00:00Z", "2020-02-09T00:00:00Z", "2020-02-10T00:00:00Z", "2020-02-11T00:00:00Z", "2020-02-12T00:00:00Z", "2020-02-13T00:00:00Z", "2020-02-14T00:00:00Z", "2020-02-15T00:00:00Z", "2020-02-16T00:00:00Z", "2020-02-17T00:00:00Z", "2020-02-18T00:00:00Z", "2020-02-19T00:00:00Z", "2020-02-20T00:00:00Z", "2020-02-21T00:00:00Z", "2020-02-22T00:00:00Z", "2020-02-23T00:00:00Z", "2020-02-24T00:00:00Z", "2020-02-25T00:00:00Z", "2020-02-26T00:00:00Z", "2020-02-27T00:00:00Z", "2020-02-28T00:00:00Z", "2020-02-29T00:00:00Z", "2020-03-01T00:00:00Z", "2020-03-02T00:00:00Z", "2020-03-03T00:00:00Z", "2020-03-04T00:00:00Z", "2020-03-05T00:00:00Z", "2020-03-06T00:00:00Z", "2020-03-07T00:00:00Z", "2020-03-08T00:00:00Z", "2020-03-09T00:00:00Z", "2020-03-10T00:00:00Z", "2020-03-11T00:00:00Z", "2020-03-12T00:00:00Z", "2020-03-13T00:00:00Z", "2020-03-14T00:00:00Z", "2020-03-15T00:00:00Z", "2020-03-16T00:00:00Z", "2020-03-17T00:00:00Z", "2020-03-18T00:00:00Z", "2020-03-19T00:00:00Z", "2020-03-20T00:00:00Z", "2020-03-21T00: